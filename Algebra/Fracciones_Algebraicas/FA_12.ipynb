# %% [markdown]
# # Matematicas con Juan

# %% [markdown]
# <img src="../../pics/cover.png" width=600>
#
# https://www.youtube.com/@matematicaconjuan

# %% [markdown]
# https://www.youtube.com/playlist?list=PLZeRcx60JO53wivRUDj-DfzwCzdugCfTY

# %%
from vpython import *
from astropy import units as u
import sympy as sp
from IPython.display import display, Math

a, m, p, q, x, y, z = sp.symbols("a, m, p, q, x, y, z", real=True)
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# # Video 12 - Simplificar
# $$\frac{x^2 -49}{x^2 -14x +49}$$

# %%
expr = (x**2 -49) / (x**2 - 14*x +49)
display(sp.Eq(expr, expr.simplify()))
# Out:
# Eq((x**2 - 49)/(x**2 - 14*x + 49), (x + 7)/(x - 7))

# %% [markdown]
# ### Tarea
# $$\frac{x^2 - 12x +36}{x^2 -36}$$

# %%
expr =  (x**2 - 12*x + 36) / (x**2 -36)
display(sp.Eq(expr, expr.simplify()))
# Out:
# Eq((x**2 - 12*x + 36)/(x**2 - 36), (x - 6)/(x + 6))
