# %% [markdown]
# # Matematicas con Juan

# %% [markdown]
# <img src="../../pics/cover.png" width=600>
#
# https://www.youtube.com/@matematicaconjuan

# %% [markdown]
# # Video 20 - División de dos fracciones algebraicas
# https://www.youtube.com/playlist?list=PLZeRcx60JO53wivRUDj-DfzwCzdugCfTY

# %%
# %pip install setuptools sympy vpython astropy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\crodr\Tutoriales\Math\Matematicas_con_Juan\.venv\Scripts\python.exe: No module named pip

# %%
from vpython import *
from astropy import units as u
import sympy as sp
from IPython.display import display, Math

a, m, n, p, q, r, s, t, u, v, x, y, z = sp.symbols(
    "a, m, n, p, q, r, s, t, u, v, x, y, z", real=True
)
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# ## Ejercicio 1
# $$\frac{2x -1}{x^2 +2x} : \frac{4x}{x^3 +2x^2}$$

# %%
expr = ((2 * x - 1) / (x**2 + 2 * x)) / ((4 * x) / (x**3 + 2 * x**2))
display(sp.Eq(expr, expr.simplify()))
# Out:
# Eq((2*x - 1)*(x**3 + 2*x**2)/(4*x*(x**2 + 2*x)), x/2 - 1/4)
