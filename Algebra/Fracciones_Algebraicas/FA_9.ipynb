# %% [markdown]
# # Matematicas con Juan

# %% [markdown]
# <img src="../../pics/cover.png" width=600>
#
# https://www.youtube.com/@matematicaconjuan

# %% [markdown]
# https://www.youtube.com/playlist?list=PLZeRcx60JO53wivRUDj-DfzwCzdugCfTY

# %%
from vpython import *
from astropy import units as u
import sympy as sp
from IPython.display import display, Math

a, m, p, q, x, y, z = sp.symbols("a, m, p, q, x, y, z", real=True)

# %% [markdown]
# # Video 9 - Libro escolar ruso
#
# $$\frac{7(a^6)^5 + 11(a^{10})^3}{(3a^{15})^2}$$

# %%
expr = (9*x**2 + 4*y**2 - (3*x -2*y)**2) / (-4*x*y)
expr
# Out:
# -(9*x**2 + 4*y**2 - (3*x - 2*y)**2)/(4*x*y)

# %% [markdown]
# ### Tarea
#
# $$\frac{11(a^3)^4 + 7(a^4)^3}{(3a^6)^2}$$

# %%
expr = (11*(a**3)**4 + 7*(a**4)**3) / ((3*a**6)**2)
expr
# Out:
# 2
