# %% [markdown]
# # Matematicas con Juan

# %% [markdown]
# <img src="../../pics/cover.png" width=600>
#
# https://www.youtube.com/@matematicaconjuan

# %% [markdown]
# # Video 18 - 100 ejercicios de Fracciones Algebraicas
# https://www.youtube.com/playlist?list=PLZeRcx60JO53wivRUDj-DfzwCzdugCfTY

# %%
from vpython import *
from astropy import units as u
import sympy as sp
from IPython.display import display, Math

m, p, x, y, z = sp.symbols("m, p, x, y, z", real=True)
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# ## Ejercicio 28
# $$\frac{9m - 3}{81m^2 - 9}$$

# %%
expr = (9*m - 3) / (81*m**2-9)
display(sp.Eq(expr, expr.simplify()))
# Out:
# Eq((9*m - 3)/(81*m**2 - 9), 1/(3*(3*m + 1)))

# %% [markdown]
# ## Ejercicio 29
# $$\frac{2x^3 - 2x}{4x+4}$$

# %%
expr = (2*x**3 - 2*x) / (4*x + 4)
display(sp.Eq(expr, expr.simplify()))
# Out:
# Eq((2*x**3 - 2*x)/(4*x + 4), x*(x - 1)/2)

# %% [markdown]
# ## Ejercicio 30
# $$\frac{2y^2 - 50}{y + 5}$$

# %%
expr = (2*y**2 - 50) / (y + 5)
display(sp.Eq(expr, expr.simplify()))
# Out:
# Eq((2*y**2 - 50)/(y + 5), 2*y - 10)

# %% [markdown]
# ## Ejercicio 31
# $$\frac{x^2 + 2x + 1}{x+1}$$

# %%
expr = (x**2 + 2*x + 1) / (x + 1)
display(sp.Eq(expr, expr.simplify()))
# Out:
# Eq((x**2 + 2*x + 1)/(x + 1), x + 1)

# %% [markdown]
# ## Ejercicio 32
# $$\frac{x^2 + 4x + 4}{x+2}$$

# %%
expr = (x**2 + 4*x + 4) / (x + 2)
display(sp.Eq(expr, expr.simplify()))
# Out:
# Eq((x**2 + 4*x + 4)/(x + 2), x + 2)

# %% [markdown]
# ## Ejercicio 33
# $$\frac{x^2 - 1}{x^2 + 2x +1}$$

# %%
expr = (x**2 - 1) / (x**2 + 2*x + 1)
display(sp.Eq(expr, expr.simplify()))
# Out:
# Eq((x**2 - 1)/(x**2 + 2*x + 1), (x - 1)/(x + 1))

# %% [markdown]
# ## Ejercicio 34
# $$\frac{x^2 - 9}{x^2 + 6x +9}$$

# %%
expr = (x**2 - 9) / (x**2 + 6*x + 9)
display(sp.Eq(expr, expr.simplify()))
# Out:
# Eq((x**2 - 9)/(x**2 + 6*x + 9), (x - 3)/(x + 3))

# %% [markdown]
# ## Ejercicio 35
# $$\frac{x^2 - 25}{x^2 - 10x +25}$$

# %%
expr = (x**2 - 25) / (x**2 - 10*x + 25)
display(sp.Eq(expr, expr.simplify()))
# Out:
# Eq((x**2 - 25)/(x**2 - 10*x + 25), (x + 5)/(x - 5))

# %% [markdown]
# ## Ejercicio 36
# $$\frac{x^2 - 6x + 9}{x - 3}$$

# %%
expr = (x**2 - 6*x + 9) / (x - 3)
display(sp.Eq(expr, expr.simplify()))
# Out:
# Eq((x**2 - 6*x + 9)/(x - 3), x - 3)

# %% [markdown]
# ## Ejercicio 37
# $$\frac{2x + 3}{4x^2 + 12x +9}$$

# %%
expr = (2*x + 3) / (4*x**2 + 12*x + 9)
display(sp.Eq(expr, expr.simplify()))
# Out:
# Eq((2*x + 3)/(4*x**2 + 12*x + 9), 1/(2*x + 3))

# %% [markdown]
# ## Ejercicio 38
# $$\frac{9x^2 - 6x +1}{6x - 2}$$

# %%
expr = (9*x**2 - 6*x + 1) / (6*x - 2)
display(sp.Eq(expr, expr.simplify()))
# Out:
# Eq((9*x**2 - 6*x + 1)/(6*x - 2), 3*x/2 - 1/2)

# %% [markdown]
# ## Ejercicio 39
# $$\frac{25x^2 - 4}{25x^2 - 20x +4}$$

# %%
expr = (25*x**2 - 4) / (25*x**2 - 20*x + 4)
display(sp.Eq(expr, expr.simplify()))
# Out:
# Eq((25*x**2 - 4)/(25*x**2 - 20*x + 4), (5*x + 2)/(5*x - 2))

# %% [markdown]
# ## Ejercicio 40
# $$\frac{16x^2 - 40x + 25}{16x^2 - 25}$$

# %%
expr = (16*x**2 - 40*x + 25) / (16*x**2 - 25)
display(sp.Eq(expr, expr.simplify()))
# Out:
# Eq((16*x**2 - 40*x + 25)/(16*x**2 - 25), (4*x - 5)/(4*x + 5))

# %% [markdown]
# ## Ejercicio 41
# $$\frac{x^3 - 1}{x^2 - 1}$$

# %%
expr = (x**3 - 1) / (x**2 - 1)
display(sp.Eq(expr, expr.factor()))
# Out:
# Eq((x**3 - 1)/(x**2 - 1), (x**2 + x + 1)/(x + 1))

# %% [markdown]
# ## Ejercicio 42
# $$\frac{x^2 - 4}{x^3 - 8}$$

# %%
expr = (x**2 - 4) / (x**3 - 8)
display(sp.Eq(expr, expr.factor()))
# Out:
# Eq((x**2 - 4)/(x**3 - 8), (x + 2)/(x**2 + 2*x + 4))

# %% [markdown]
# ## Ejercicio 43
# $$\frac{x^2 - x + 1}{x^3 +1}$$

# %%
expr = (x**2 - x + 1) / (x**3 + 1)
display(sp.Eq(expr, expr.factor()))
# Out:
# Eq((x**2 - x + 1)/(x**3 + 1), 1/(x + 1))

# %% [markdown]
# ## Ejercicio 44
# $$\frac{x^3 + 27}{x^2 + 6x + 9}$$

# %%
expr = (x**3 + 27) / (x**2 + 6*x + 9)
display(sp.Eq(expr, expr.factor()))
# Out:
# Eq((x**3 + 27)/(x**2 + 6*x + 9), (x**2 - 3*x + 9)/(x + 3))

# %% [markdown]
# ## Ejercicio 45
# $$\frac{4x^2 + 12x + 9}{8x^3 +27}$$

# %%
expr = (4*x**2 + 12*x + 9) / (8*x**3 + 27)
display(sp.Eq(expr, expr.factor()))
# Out:
# Eq((4*x**2 + 12*x + 9)/(8*x**3 + 27), (2*x + 3)/(4*x**2 - 6*x + 9))

# %% [markdown]
# ## Ejercicio 46
# $$\frac{2x^2 + 6x + 18}{x^3 -27}$$

# %%
expr = (2*x**2 + 6*x + 18) / (x**3 - 27)
display(sp.Eq(expr, expr.factor()))
# Out:
# Eq((2*x**2 + 6*x + 18)/(x**3 - 27), 2/(x - 3))

# %% [markdown]
# ## Ejercicio 47
# $$\frac{x^3 - 8}{x^2 -2x}$$

# %%
expr = (x**3 - 8) / (x**2 - 2*x)
display(sp.Eq(expr, expr.factor()))
# Out:
# Eq((x**3 - 8)/(x**2 - 2*x), (x**2 + 2*x + 4)/x)

# %% [markdown]
# ## Ejercicio 48
# $$\frac{x^3 - 27}{x^2 +3x +9}$$

# %%
expr = (x**3 - 27) / (x**2 + 3*x +9)
display(sp.Eq(expr, expr.factor()))
# Out:
# Eq((x**3 - 27)/(x**2 + 3*x + 9), x - 3)

# %% [markdown]
# ## Ejercicio 49
# $$\frac{x^2 +2x + 4}{x^3 -8}$$

# %%
expr = (x**2 +2*x + 4) / (x**3 -8)
display(sp.Eq(expr, expr.factor()))
# Out:
# Eq((x**2 + 2*x + 4)/(x**3 - 8), 1/(x - 2))

# %% [markdown]
# ## Ejercicio 50
# $$\frac{2x - 6}{10x^3 -270}$$

# %%
expr = (2*x -6) / (10*x**3 -270)
display(sp.Eq(expr, expr.factor()))
# Out:
# Eq((2*x - 6)/(10*x**3 - 270), 1/(5*(x**2 + 3*x + 9)))
